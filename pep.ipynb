# %%
import yaml
import pandas as pd


customer_demo = 'data_files/customer_demographics.yaml'
# Load YAML data from a file
with open(customer_demo, 'r') as yaml_file:
    yaml_data = yaml.safe_load(yaml_file)

# Create a list of dictionaries with the desired column names
data_list = []
for customer_id, details in yaml_data.items():
    data_list.append({
        'address': details.get('address'),
        'city': details.get('city'),
        'credit_card_expires': details.get('credit_card_expires'),
        'credit_card_number': details.get('credit_card_number'),
        'credit_card_provider': details.get('credit_card_provider'),
        'credit_card_security_code': details.get('credit_card_security_code'),
        'customer_id': details.get('customer_id'),
        'email': details.get('email'),
        'name': details.get('name'),
        'phone_number': details.get('phone_number'),
        'state': details.get('state'),
        'zip_code': details.get('zip_code'),
    })

# Convert the list of dictionaries to Pandas DataFrame
cust_demo = pd.DataFrame(data_list)

# %%
cust_demo.head()
# Out:
#                       address             city credit_card_expires  \
# 0   621 Chavez Ramp Suite 938  West Deniseport               06/31
# 1             592 Mccoy River  Port Dannymouth               11/24
# 2         8923 Aaron Turnpike   Port Rhondaton               11/31
# 3         496 Margaret Shoals     Smithborough               04/33
# 4  0807 Logan Fords Suite 355    Contrerasside               10/25
#
#     credit_card_number         credit_card_provider credit_card_security_code  \
# 0     2269172571677458  Diners Club / Carte Blanche                       338
# 1         676320507830                 JCB 16 digit                       246
# 2  4607779976715144588                 JCB 16 digit                       869
# 3     4234465830748237                   Mastercard                       497
# 4        4985681645741                     Discover                       927
#
#                             customer_id                       email  \
# 0  a8c966a0-b670-4044-826c-0e6bfe708259         brett00@example.com
# 1  56b850e0-9320-4aa0-8cd4-d1199903c90e   smithjennifer@example.net
# 2  5ec9f613-adb1-4e69-8a1a-9530cb777886          twhite@example.net
# 3  ca182662-b281-433a-a82b-8e061f7bf2cd  nguyenjennifer@example.com
# 4  1e7c3a60-4788-4711-809f-b6f8bfbdb18a    michaelabarr@example.net
#
#                  name           phone_number         state zip_code
# 0      Ronald Rodgers                   None      New York    59237
# 1       Mary Mitchell                   None       Montana    17401
# 2        Nathan Wells    +1-893-568-2182x593  North Dakota    07166
# 3         Kelly Ramos           820-824-2003          Iowa    42755
# 4  Rebekah Fitzgerald  +1-269-384-1623x34240   Connecticut    64282

# %%
cust_stat = pd.read_csv('data_files/customer_statistics.csv')

# %%
cust_stat.head()
# Out:
#    customer_id  total_orders  total_items  total_spent
# 0         8037             5           20       300.39
# 1         4290             2            3       332.66
# 2         5367             3            7       643.27
# 3         4755            10           12       649.12
# 4         2651            10            9       794.28

# %%
orders = pd.read_csv('data_files/orders (1).csv')

# %%
orders.head()
# Out:
#                                order_id  customer_id  items      aperitifs  \
# 0  f1d6b4c4-0f9f-4ba6-8d5d-f7e4ef7cd9a0         2652      7  Aperol Spritz
# 1  7b8a732e-85a0-4fa2-b282-a2d232ee182e         1756      3         Sherry
# 2  1eab436d-2acb-4bc8-b849-fbce859ffd8a         2989      5        Bellini
# 3  d6313392-8901-42f6-bf8a-4805fe816a46         9903      3         Sherry
# 4  f73f8c45-28c2-473f-a3ba-e65ed5890ac6         8627      2           Port
#
#   appetizers  entrees        desserts   total
# 0       Pate     Pork        Tiramisu  751.87
# 1       Pate    Pasta      Cheesecake  156.43
# 2       Pate  Lobster  Chocolate Cake  364.13
# 3      Salad    Pizza      Cheesecake  805.62
# 4       Pate  Lobster             Pie  638.43

# %%
merged_data = cust_demo.merge(cust_stat, left_index=True, right_index=True)

# %%
merged_data.head()
# Out:
#                       address             city credit_card_expires  \
# 0   621 Chavez Ramp Suite 938  West Deniseport               06/31
# 1             592 Mccoy River  Port Dannymouth               11/24
# 2         8923 Aaron Turnpike   Port Rhondaton               11/31
# 3         496 Margaret Shoals     Smithborough               04/33
# 4  0807 Logan Fords Suite 355    Contrerasside               10/25
#
#     credit_card_number         credit_card_provider credit_card_security_code  \
# 0     2269172571677458  Diners Club / Carte Blanche                       338
# 1         676320507830                 JCB 16 digit                       246
# 2  4607779976715144588                 JCB 16 digit                       869
# 3     4234465830748237                   Mastercard                       497
# 4        4985681645741                     Discover                       927
#
#                           customer_id_x                       email  \
# 0  a8c966a0-b670-4044-826c-0e6bfe708259         brett00@example.com
# 1  56b850e0-9320-4aa0-8cd4-d1199903c90e   smithjennifer@example.net
# 2  5ec9f613-adb1-4e69-8a1a-9530cb777886          twhite@example.net
# 3  ca182662-b281-433a-a82b-8e061f7bf2cd  nguyenjennifer@example.com
# 4  1e7c3a60-4788-4711-809f-b6f8bfbdb18a    michaelabarr@example.net
#
#                  name           phone_number         state zip_code  \
# 0      Ronald Rodgers                   None      New York    59237
# 1       Mary Mitchell                   None       Montana    17401
# 2        Nathan Wells    +1-893-568-2182x593  North Dakota    07166
# 3         Kelly Ramos           820-824-2003          Iowa    42755
# 4  Rebekah Fitzgerald  +1-269-384-1623x34240   Connecticut    64282
#
#    customer_id_y  total_orders  total_items  total_spent
# 0           8037             5           20       300.39
# 1           4290             2            3       332.66
# 2           5367             3            7       643.27
# 3           4755            10           12       649.12
# 4           2651            10            9       794.28

# %%
data_duplicates = merged_data.duplicated()

merged_data.drop_duplicates(inplace=True)

# %%
merged_data
# Out:
#                             address                 city credit_card_expires  \
# 0         621 Chavez Ramp Suite 938      West Deniseport               06/31
# 1                   592 Mccoy River      Port Dannymouth               11/24
# 2               8923 Aaron Turnpike       Port Rhondaton               11/31
# 3               496 Margaret Shoals         Smithborough               04/33
# 4        0807 Logan Fords Suite 355        Contrerasside               10/25
# ...                             ...                  ...                 ...
# 9995             419 Lopez Crossing  North Nicolechester               01/30
# 9996            38594 Franklin Pine          Port Joshua               01/31
# 9997  535 Kimberly Station Apt. 546           Garzaville               07/24
# 9998            35316 Becky Terrace          Port Donald               04/24
# 9999  6101 Thompson Ridges Apt. 896         Marissamouth               05/25
#
#        credit_card_number         credit_card_provider  \
# 0        2269172571677458  Diners Club / Carte Blanche
# 1            676320507830                 JCB 16 digit
# 2     4607779976715144588                 JCB 16 digit
# 3        4234465830748237                   Mastercard
# 4           4985681645741                     Discover
# ...                   ...                          ...
# 9995         639083591672                VISA 13 digit
# 9996     4197551271949528                VISA 13 digit
# 9997       36597049683777                VISA 16 digit
# 9998     6595168672629675                 JCB 16 digit
# 9999  4999092953838318200  Diners Club / Carte Blanche
#
#      credit_card_security_code                         customer_id_x  \
# 0                          338  a8c966a0-b670-4044-826c-0e6bfe708259
# 1                          246  56b850e0-9320-4aa0-8cd4-d1199903c90e
# 2                          869  5ec9f613-adb1-4e69-8a1a-9530cb777886
# 3                          497  ca182662-b281-433a-a82b-8e061f7bf2cd
# 4                          927  1e7c3a60-4788-4711-809f-b6f8bfbdb18a
# ...                        ...                                   ...
# 9995                       079  0707f817-5018-4060-b01c-2c5b53374a2e
# 9996                       237  abc92c1c-788c-4e61-a40d-c6754c99bdc7
# 9997                       287  418cc301-e111-4080-b8f7-8d9f1d9dc304
# 9998                       113  7caf0251-8040-4c1e-8190-46133fde16ab
# 9999                       810  3b343ad7-9d47-43c6-98d7-8a1c0bfebf12
#
#                            email                name           phone_number  \
# 0            brett00@example.com      Ronald Rodgers                   None
# 1      smithjennifer@example.net       Mary Mitchell                   None
# 2             twhite@example.net        Nathan Wells    +1-893-568-2182x593
# 3     nguyenjennifer@example.com         Kelly Ramos           820-824-2003
# 4       michaelabarr@example.net  Rebekah Fitzgerald  +1-269-384-1623x34240
# ...                          ...                 ...                    ...
# 9995    andrewrogers@example.net      Tracey Edwards  001-555-466-6738x7224
# 9996         sduncan@example.com     Ashley Peterson          (434)761-1066
# 9997       rhatfield@example.net   Sandra Baldwin MD     867.829.9891x64114
# 9998  andreawilliams@example.org         Karen Green                   None
# 9999     anthonykemp@example.net     Marissa Garrett                   None
#
#              state zip_code  customer_id_y  total_orders  total_items  \
# 0         New York    59237           8037             5           20
# 1          Montana    17401           4290             2            3
# 2     North Dakota    07166           5367             3            7
# 3             Iowa    42755           4755            10           12
# 4      Connecticut    64282           2651            10            9
# ...            ...      ...            ...           ...          ...
# 9995       Alabama    15476            585            10           14
# 9996    New Jersey    58035           4604             2            1
# 9997   Connecticut    16016           5168             7            8
# 9998        Nevada    97426           3722             5            1
# 9999        Nevada    22202           2911             2            8
#
#       total_spent
# 0          300.39
# 1          332.66
# 2          643.27
# 3          649.12
# 4          794.28
# ...           ...
# 9995       394.88
# 9996       858.88
# 9997       137.52
# 9998       105.75
# 9999       918.60
#
# [10000 rows x 16 columns]
